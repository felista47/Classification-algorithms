# %% [markdown]
# <a href="https://colab.research.google.com/github/felista47/Classification-algorithms/blob/main/MultiLinearModelTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#reading the data
data_multi=pd.read_excel("/content/drive/My Drive/ENGAGE/Datasets/MultiLinearRegressionPractical/child_health_data_bungoma_county.xlsx")
#displaying the first five rows
data_multi.head()
# Out:
#    Cluster number  Household number  Line number  Cluster number.1  \
# 0               1                 5            3                 1
# 1               1                 6            4                 1
# 2               1                 9            5                 1
# 3               1                 9            7                 1
# 4               1                14            6                 1
#
#    Household number.1  Child's line number  Mother / Caretaker's line number  \
# 0                   5                    3                                 2
# 1                   6                    4                                 1
# 2                   9                    5                                 2
# 3                   9                    7                                 2
# 4                  14                    6                                 2
#
#    Day of interview  Month of interview  Year of interview  ... Age in days  \
# ...

# %%
data_multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874 entries, 0 to 873
# Columns: 300 entries, Cluster number to Rural wealth index quintile
# dtypes: float64(31), int64(11), object(258)
# memory usage: 2.0+ MB

# %%
data_multi.columns
# Out:
# Index(['Cluster number', 'Household number', 'Line number', 'Cluster number.1',
#        'Household number.1', 'Child's line number',
#        'Mother / Caretaker's line number', 'Day of interview',
#        'Month of interview', 'Year of interview',
#        ...
#        'Age in days', 'Mother's education', 'Ethnicity of household head',
#        'Children's sample weight', 'Combined wealth score',
#        'Wealth index quintile', 'Urban wealth score',
#        'Urban wealth index quintile', 'Rural wealth score',
#        'Rural wealth index quintile'],
#       dtype='object', length=300)

# %%
new_data=data_multi[["Age (months)","Sex","Mother's education","Area","Wealth index quintile","Child's length or height (centimetres)","Child's weight (kilograms)","Body Mass Index WHO"]]
new_data.head()
# Out:
#    Age (months)     Sex Mother's education   Area Wealth index quintile  \
# 0          45.0  Female         Secondary+  Rural               Richest
# 1          45.0    Male            Primary  Rural                Second
# 2          36.0    Male            Primary  Rural                Fourth
# 3          51.0  Female            Primary  Rural                Fourth
# 4          56.0  Female            Primary  Rural                Fourth
#
#    Child's length or height (centimetres) Child's weight (kilograms)  \
# 0                                   102.4                       16.2
# 1                                    92.5                       13.5
# 2                                    88.5                       13.4
# 3                                   101.3                         15
# 4                                   105.0                       15.2
#
#   Body Mass Index WHO
# 0               15.45
# 1               15.78
# 2               17.11
# 3               14.62
# ...

# %%
new_data.isnull().sum()
# Out:
# Age (months)                              28
# Sex                                        0
# Mother's education                        32
# Area                                       0
# Wealth index quintile                      0
# Child's length or height (centimetres)    65
# Child's weight (kilograms)                65
# Body Mass Index WHO                       28
# dtype: int64

# %%
new_data.dropna(inplace=True)
# Out:
# <ipython-input-9-a2eb0d94fae1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.dropna(inplace=True)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 778 entries, 0 to 873
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Age (months)                            778 non-null    float64
#  1   Sex                                     778 non-null    object
#  2   Mother's education                      778 non-null    object
#  3   Area                                    778 non-null    object
#  4   Wealth index quintile                   778 non-null    object
#  5   Child's length or height (centimetres)  778 non-null    float64
#  6   Child's weight (kilograms)              778 non-null    object
#  7   Body Mass Index WHO                     778 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 54.7+ KB

# %%
new_data.shape
# Out:
# (778, 8)

# %%
# Save work in progress data for later use
new_data.to_excel("/content/drive/My Drive/ENGAGE/Datasets/MultiLinearRegressionPractical/child_health_data_bungoma_county_still_in_progress3.xlsx", index=False)

# %%
#checking to see if there are still missing values in the dataset
new_data.isnull().sum()
# Out:
# Age (months)                              0
# Sex                                       0
# Mother's education                        0
# Area                                      0
# Wealth index quintile                     0
# Child's length or height (centimetres)    0
# Child's weight (kilograms)                0
# Body Mass Index WHO                       0
# dtype: int64

# %%
new_data["Sex"]=pd.get_dummies(new_data["Sex"], dtype=int,drop_first=True)
new_data["Mother's education"]=pd.get_dummies(new_data["Mother's education"], dtype=int,drop_first=True)
new_data["Area"]=pd.get_dummies(new_data["Area"], dtype=int,drop_first=True)
new_data.head()
# Out:
# <ipython-input-14-4d6b826bc8c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Sex"]=pd.get_dummies(new_data["Sex"], dtype=int,drop_first=True)
# <ipython-input-14-4d6b826bc8c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Mother's education"]=pd.get_dummies(new_data["Mother's education"], dtype=int,drop_first=True)
# <ipython-input-14-4d6b826bc8c3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
new_data["Wealth index quintile"]= pd.factorize(new_data["Wealth index quintile"])[0]
new_data.head(10)
# Out:
# <ipython-input-15-bcd5f7913d0c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Wealth index quintile"]= pd.factorize(new_data["Wealth index quintile"])[0]
#    Age (months)  Sex  Mother's education  Area  Wealth index quintile  \
# 0          45.0    0                   1     0                      0
# 1          45.0    1                   0     0                      1
# 2          36.0    1                   0     0                      2
# 3          51.0    0                   0     0                      2
# 4          56.0    0                   0     0                      2
# 5          20.0    0                   0     0                      2
# 6           4.0    0                   0     0                      2
# ...

# %%
# Save cleaned data for training and prediction
new_data.to_excel("/content/drive/My Drive/ENGAGE/Datasets/MultiLinearRegressionPractical/child_data20.xlsx", index=False)

# %%
final_data=pd.read_excel("/content/drive/My Drive/ENGAGE/Datasets/MultiLinearRegressionPractical/child_data20.xlsx")
final_data.head()
# Out:
#    Age (months)  Sex  Mother's education  Area  Wealth index quintile  \
# 0            45    0                   1     0                      0
# 1            45    1                   0     0                      1
# 2            36    1                   0     0                      2
# 3            51    0                   0     0                      2
# 4            56    0                   0     0                      2
#
#    Child's length or height (centimetres) Child's weight (kilograms)  \
# 0                                   102.4                       16.2
# 1                                    92.5                       13.5
# 2                                    88.5                       13.4
# 3                                   101.3                         15
# 4                                   105.0                       15.2
#
#   Body Mass Index WHO
# 0               15.45
# 1               15.78
# 2               17.11
# 3               14.62
# ...

# %%
x=new_data.drop(columns=["Child's length or height (centimetres)","Child's weight (kilograms)","Body Mass Index WHO"])

# %%
#creating the output variable
y=new_data["Child's length or height (centimetres)"]

# %%
#Creating the model
model=linear_model.LinearRegression()

# %%
#spliting the data set into train and test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
#training the model using the training data data
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#predicting the values for the x_testing values
y_predict=model.predict(x_test)

# %%
y_predict2=model.predict([[60,1,0,1,2]])
print(y_predict2)
# Out:
# [106.41915333]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import r2_score, mean_absolute_error

#Evaluating the performance of the model
print("R_squared")
r_squa=r2_score(y_test,y_predict)
adjusted_r2 = 1 - (1 - r_squa) * (402 - 1) / (402 - 5 - 1)
print("Adjusted R", adjusted_r2)
print(r2_score(y_test,y_predict))
print("Mean absolute error")
print(mean_absolute_error(y_test,y_predict))
# Out:
# R_squared
# Adjusted R 0.7832066880131074
# 0.7859098465166847
# Mean absolute error
# 4.8944637650547955

# %%
model_lasso=linear_model.Lasso(alpha=0.1)

# %%
model_lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_predict_lasso=model_lasso.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

#Evaluating the performance of the model
print("R_squared")
r_squa=r2_score(y_test,y_predict_lasso)
adjusted_r2 = 1 - (1 - r_squa) * (402 - 1) / (402 - 5 - 1)
print("Adjusted R", adjusted_r2)
print(r2_score(y_test,y_predict_lasso))
print("Mean absolute error")
print(mean_absolute_error(y_test,y_predict_lasso))
# Out:
# R_squared
# Adjusted R 0.7855224082447937
# 0.7881966924312676
# Mean absolute error
# 4.856361790234363

# %%
from sklearn.linear_model import Ridge
# Initialize the Ridge regression model with a specific alpha value
ridge_model = Ridge(alpha=1.0)

# Fit the model to the training data
ridge_model.fit(x_train, y_train)

# Make predictions on the test data
y_pred_ridge = ridge_model.predict(x_test)

# %%
#Evaluating the performance of the model
print("R_squared")
r_squa=r2_score(y_test,y_pred_ridge)
adjusted_r2 = 1 - (1 - r_squa) * (402 - 1) / (402 - 5 - 1)
print("Adjusted R", adjusted_r2)
print(r2_score(y_test,y_pred_ridge))
print("Mean absolute error")
print(mean_absolute_error(y_test,y_pred_ridge))
# Out:
# R_squared
# Adjusted R 0.7832975055209477
# 0.7859995316366466
# Mean absolute error
# 4.893290042385316
